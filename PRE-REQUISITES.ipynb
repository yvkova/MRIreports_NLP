# %% [markdown]
# # PRE-REQUISITES

# %%
#Preprocessing
# !pip install stop-words
# !python -m nltk.downloader punkt
# !python -m nltk.downloader wordnet
# !python -m nltk.downloader stopwords
# !python -m nltk.downloader averaged_perceptron_tagger
# !pip install sentence-transformers
# !pip install umap-learn
# !pip install gensim
import nltk
nltk.download('omw-1.4')

# !pip install nlpaug
# !pip install sacremoses
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for stop-words: filename=stop_words-2018.7.23-py3-none-any.whl size=32911 sha256=74142a526b5797c378d6058a6a45d5b528e175288f1e1fd8cbf6c43653db3894
#   Stored in directory: /root/.cache/pip/wheels/fb/86/b2/277b10b1ce9f73ce15059bf6975d4547cc4ec3feeb651978e9
# Successfully built stop-words
# ...
# /usr/lib/python3.7/runpy.py:125: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# /usr/lib/python3.7/runpy.py:125: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# ...

# %%
USING_COLAB = True
DRIVE_LOCATION = None

if USING_COLAB:
  #Mounting to Google Colab drive
  from google.colab import drive 
  drive.mount('/content/gdrive')
  DRIVE_LOCATION = '/content/gdrive/MyDrive/Colab Notebooks/MSc Project/'
else:
  #python code is executed from the working directory
  DATA_PATH = ''
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Open terminal and install dependency sent2vec
#
# ```
# cd sent2vec-master
# pip install .
# ```

# %%
# !cp /content/gdrive/MyDrive/Colab\ Notebooks/MSc\ Project/preprocess.py /content
# !cp /content/gdrive/MyDrive/Colab\ Notebooks/MSc\ Project/vec_embeddings.py /content
# !cp /content/gdrive/MyDrive/Colab\ Notebooks/MSc\ Project/usl_model.py /content
# !cp /content/gdrive/MyDrive/Colab\ Notebooks/MSc\ Project/evaluation_metrics.py /content
# !cp /content/gdrive/MyDrive/Colab\ Notebooks/MSc\ Project/autoencoder.py /content
# !cp /content/gdrive/MyDrive/Colab\ Notebooks/MSc\ Project/pca.py /content
# !cp -r /content/gdrive/MyDrive/Colab\ Notebooks/MSc\ Project/files/sent2vec-master /content
# !cp /content/gdrive/MyDrive/Colab\ Notebooks/MSc\ Project/data_augmentation.py /content
# !cp /content/gdrive/MyDrive/Colab\ Notebooks/MSc\ Project/eda.py /content
# !cp /content/gdrive/MyDrive/Colab\ Notebooks/MSc\ Project/utils.py /content
# !cp /content/gdrive/MyDrive/Colab\ Notebooks/MSc\ Project/main.py /content
